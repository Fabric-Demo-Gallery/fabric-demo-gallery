# %% [markdown]
# # Bronze Layer — Ingest Raw Professional-Services Data
# Reads CSV files from lakehouse `{{DATA_SOURCE_PATH}}/` and writes Delta tables with metadata columns.

# %%
from pyspark.sql.functions import current_timestamp, input_file_name, lit
import uuid

ingestion_batch_id = str(uuid.uuid4())

# %%
# Ingest clients
df = (
    spark.read.format('csv').option('header', True).option('inferSchema', True)
    .load('{{DATA_SOURCE_PATH}}/clients.csv')
    .withColumn('ingestion_timestamp', current_timestamp())
    .withColumn('source_file', input_file_name())
    .withColumn('ingestion_batch_id', lit(ingestion_batch_id))
)
df.write.mode('overwrite').format('delta').saveAsTable('bronze_clients')
print(f'bronze_clients: {spark.table("bronze_clients").count()} rows')

# %%
# Ingest consultants
df = (
    spark.read.format('csv').option('header', True).option('inferSchema', True)
    .load('{{DATA_SOURCE_PATH}}/consultants.csv')
    .withColumn('ingestion_timestamp', current_timestamp())
    .withColumn('source_file', input_file_name())
    .withColumn('ingestion_batch_id', lit(ingestion_batch_id))
)
df.write.mode('overwrite').format('delta').saveAsTable('bronze_consultants')
print(f'bronze_consultants: {spark.table("bronze_consultants").count()} rows')

# %%
# Ingest engagements
df = (
    spark.read.format('csv').option('header', True).option('inferSchema', True)
    .load('{{DATA_SOURCE_PATH}}/engagements.csv')
    .withColumn('ingestion_timestamp', current_timestamp())
    .withColumn('source_file', input_file_name())
    .withColumn('ingestion_batch_id', lit(ingestion_batch_id))
)
df.write.mode('overwrite').format('delta').saveAsTable('bronze_engagements')
print(f'bronze_engagements: {spark.table("bronze_engagements").count()} rows')

# %%
# Ingest timesheets
df = (
    spark.read.format('csv').option('header', True).option('inferSchema', True)
    .load('{{DATA_SOURCE_PATH}}/timesheets.csv')
    .withColumn('ingestion_timestamp', current_timestamp())
    .withColumn('source_file', input_file_name())
    .withColumn('ingestion_batch_id', lit(ingestion_batch_id))
)
df.write.mode('overwrite').format('delta').saveAsTable('bronze_timesheets')
print(f'bronze_timesheets: {spark.table("bronze_timesheets").count()} rows')
