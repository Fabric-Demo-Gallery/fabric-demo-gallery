# %% [markdown]
# # Bronze Layer — Ingest Raw Media Data
# Reads CSV files from lakehouse `{{DATA_SOURCE_PATH}}/` and writes Delta tables with metadata columns.

# %%
from pyspark.sql.functions import current_timestamp, input_file_name, lit
import uuid

ingestion_batch_id = str(uuid.uuid4())

# %%
# Ingest content_catalog
df = (
    spark.read.format('csv').option('header', True).option('inferSchema', True)
    .load('{{DATA_SOURCE_PATH}}/content_catalog.csv')
    .withColumn('ingestion_timestamp', current_timestamp())
    .withColumn('source_file', input_file_name())
    .withColumn('ingestion_batch_id', lit(ingestion_batch_id))
)
df.write.mode('overwrite').format('delta').saveAsTable('bronze_content')
print(f'bronze_content: {spark.table("bronze_content").count()} rows')

# %%
# Ingest subscribers
df = (
    spark.read.format('csv').option('header', True).option('inferSchema', True)
    .load('{{DATA_SOURCE_PATH}}/subscribers.csv')
    .withColumn('ingestion_timestamp', current_timestamp())
    .withColumn('source_file', input_file_name())
    .withColumn('ingestion_batch_id', lit(ingestion_batch_id))
)
df.write.mode('overwrite').format('delta').saveAsTable('bronze_subscribers')
print(f'bronze_subscribers: {spark.table("bronze_subscribers").count()} rows')

# %%
# Ingest viewing_history
df = (
    spark.read.format('csv').option('header', True).option('inferSchema', True)
    .load('{{DATA_SOURCE_PATH}}/viewing_history.csv')
    .withColumn('ingestion_timestamp', current_timestamp())
    .withColumn('source_file', input_file_name())
    .withColumn('ingestion_batch_id', lit(ingestion_batch_id))
)
df.write.mode('overwrite').format('delta').saveAsTable('bronze_viewing')
print(f'bronze_viewing: {spark.table("bronze_viewing").count()} rows')

# %%
# Ingest ad_impressions
df = (
    spark.read.format('csv').option('header', True).option('inferSchema', True)
    .load('{{DATA_SOURCE_PATH}}/ad_impressions.csv')
    .withColumn('ingestion_timestamp', current_timestamp())
    .withColumn('source_file', input_file_name())
    .withColumn('ingestion_batch_id', lit(ingestion_batch_id))
)
df.write.mode('overwrite').format('delta').saveAsTable('bronze_ad_impressions')
print(f'bronze_ad_impressions: {spark.table("bronze_ad_impressions").count()} rows')
