# %% [markdown]
# # Bronze Layer — Ingest Raw Hospitality Data
# Reads CSV files from lakehouse `{{DATA_SOURCE_PATH}}/` and writes Delta tables with metadata columns.

# %%
from pyspark.sql.functions import current_timestamp, input_file_name, lit
import uuid

ingestion_batch_id = str(uuid.uuid4())

# %%
# Ingest properties
df = (
    spark.read.format('csv').option('header', True).option('inferSchema', True)
    .load('{{DATA_SOURCE_PATH}}/properties.csv')
    .withColumn('ingestion_timestamp', current_timestamp())
    .withColumn('source_file', input_file_name())
    .withColumn('ingestion_batch_id', lit(ingestion_batch_id))
)
df.write.mode('overwrite').format('delta').saveAsTable('bronze_properties')
print(f'bronze_properties: {spark.table("bronze_properties").count()} rows')

# %%
# Ingest guests
df = (
    spark.read.format('csv').option('header', True).option('inferSchema', True)
    .load('{{DATA_SOURCE_PATH}}/guests.csv')
    .withColumn('ingestion_timestamp', current_timestamp())
    .withColumn('source_file', input_file_name())
    .withColumn('ingestion_batch_id', lit(ingestion_batch_id))
)
df.write.mode('overwrite').format('delta').saveAsTable('bronze_guests')
print(f'bronze_guests: {spark.table("bronze_guests").count()} rows')

# %%
# Ingest bookings
df = (
    spark.read.format('csv').option('header', True).option('inferSchema', True)
    .load('{{DATA_SOURCE_PATH}}/bookings.csv')
    .withColumn('ingestion_timestamp', current_timestamp())
    .withColumn('source_file', input_file_name())
    .withColumn('ingestion_batch_id', lit(ingestion_batch_id))
)
df.write.mode('overwrite').format('delta').saveAsTable('bronze_bookings')
print(f'bronze_bookings: {spark.table("bronze_bookings").count()} rows')

# %%
# Ingest reviews
df = (
    spark.read.format('csv').option('header', True).option('inferSchema', True)
    .load('{{DATA_SOURCE_PATH}}/reviews.csv')
    .withColumn('ingestion_timestamp', current_timestamp())
    .withColumn('source_file', input_file_name())
    .withColumn('ingestion_batch_id', lit(ingestion_batch_id))
)
df.write.mode('overwrite').format('delta').saveAsTable('bronze_reviews')
print(f'bronze_reviews: {spark.table("bronze_reviews").count()} rows')
