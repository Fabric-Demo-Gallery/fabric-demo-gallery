# %% [markdown]
# # Bronze Layer — Ingest Raw Construction Data
# Reads CSV files from lakehouse `{{DATA_SOURCE_PATH}}/` and writes Delta tables with metadata columns.

# %%
from pyspark.sql.functions import current_timestamp, input_file_name, lit
import uuid

ingestion_batch_id = str(uuid.uuid4())

# %%
# Ingest subcontractors
df = (
    spark.read.format('csv').option('header', True).option('inferSchema', True)
    .load('{{DATA_SOURCE_PATH}}/subcontractors.csv')
    .withColumn('ingestion_timestamp', current_timestamp())
    .withColumn('source_file', input_file_name())
    .withColumn('ingestion_batch_id', lit(ingestion_batch_id))
)
df.write.mode('overwrite').format('delta').saveAsTable('bronze_subcontractors')
print(f'bronze_subcontractors: {spark.table("bronze_subcontractors").count()} rows')

# %%
# Ingest projects
df = (
    spark.read.format('csv').option('header', True).option('inferSchema', True)
    .load('{{DATA_SOURCE_PATH}}/projects.csv')
    .withColumn('ingestion_timestamp', current_timestamp())
    .withColumn('source_file', input_file_name())
    .withColumn('ingestion_batch_id', lit(ingestion_batch_id))
)
df.write.mode('overwrite').format('delta').saveAsTable('bronze_projects')
print(f'bronze_projects: {spark.table("bronze_projects").count()} rows')

# %%
# Ingest tasks
df = (
    spark.read.format('csv').option('header', True).option('inferSchema', True)
    .load('{{DATA_SOURCE_PATH}}/tasks.csv')
    .withColumn('ingestion_timestamp', current_timestamp())
    .withColumn('source_file', input_file_name())
    .withColumn('ingestion_batch_id', lit(ingestion_batch_id))
)
df.write.mode('overwrite').format('delta').saveAsTable('bronze_tasks')
print(f'bronze_tasks: {spark.table("bronze_tasks").count()} rows')

# %%
# Ingest cost_ledger
df = (
    spark.read.format('csv').option('header', True).option('inferSchema', True)
    .load('{{DATA_SOURCE_PATH}}/cost_ledger.csv')
    .withColumn('ingestion_timestamp', current_timestamp())
    .withColumn('source_file', input_file_name())
    .withColumn('ingestion_batch_id', lit(ingestion_batch_id))
)
df.write.mode('overwrite').format('delta').saveAsTable('bronze_cost_ledger')
print(f'bronze_cost_ledger: {spark.table("bronze_cost_ledger").count()} rows')
